# %% [markdown]
# 👉 Supabase 데이터 잘 불러오는지 확인

# %% [markdown]
# 경로 설정

# %%
import sys, os
sys.path.append(os.path.abspath("../src"))

# %% [markdown]
# 데이터 로드

# %%
from database.repository import load_table

products = load_table("products")
reviews = load_table("review")
questions = load_table("questions")
sellers = load_table("sellers")

products.head(), reviews.head(), questions.head(), sellers.head()

# %% [markdown]
# shape 확인

# %%
print("products:", products.shape)
print("reviews:", reviews.shape)
print("questions:", questions.shape)
print("sellers:", sellers.shape)
